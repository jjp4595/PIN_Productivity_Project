# %%
#Importing packages
import osmnx as ox
import geopandas
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
from sklearn.preprocessing import minmax_scale

# %%
#Importing shape files
sheff_OShighways = geopandas.read_file(r"C:\Users\cip18jjp\Dropbox\PIN\1 Data\1 Data\Workshop_2_data\Sheffield_OA.shp")
#sheff = geopandas.read_file(r"C:\Users\cip18jjp\Dropbox\PIN\1 Data\1 Data\Workshop_2_data\Sheffield_Network.gdb")
sheff_lsoa_shape = geopandas.read_file(r"C:\Users\cip18jjp\Dropbox\PIN\1 Data\1 Data\CDRC\Census Data Pack\Sheffield\shapefiles\Sheffield_lsoa11.shp")
sheff_msoa_shape = geopandas.read_file(r"C:\Users\cip18jjp\Dropbox\PIN\1 Data\1 Data\CDRC\Census Data Pack\Sheffield\shapefiles\Sheffield_msoa11.shp")

# %%
#Import Population data
sheff_lsoa_pop = geopandas.read_file(r"C:\Users\cip18jjp\Dropbox\PIN\1 Data\1 Data\CDRC\Census Data Pack\Sheffield\tables\KS101EW_lsoa11.csv")
sheff_lsoa_pop['KS101EW0001'] = pd.to_numeric(sheff_lsoa_pop['KS101EW0001']) #Count: All categories:sex

# %%
#Income Distributions
sheff_lsoa_income = geopandas.read_file(r"C:\Users\cip18jjp\Dropbox\PIN\1 Data\1 Data\CDRC\Individual LSOA Income Estimate\E37000040\spatial\E37000040.shp")

#Remove lsoa's that aren't in census data so income & pop are same size
ids = sheff_lsoa_income['lsoa11cd'].isin(sheff_lsoa_pop['GeographyCode'].values)
ids = np.where(ids==True)
sheff_lsoa_income = sheff_lsoa_income.iloc[ids]

# %%
#Indexing 25 evenly spaced from array
idx = np.round(np.linspace(0, len(sheff_lsoa_income) - 1, 25)).astype(int)


fig = plt.figure(figsize=(18,16))
fig.suptitle('LSOA income distribution sample', fontsize=16)
ax0 = fig.add_subplot(5,5,1)
for i in range(len(idx)):
    ax = fig.add_subplot(5,5,i+1, sharex = ax0, sharey = ax0)
    ax = sheff_lsoa_income.iloc[idx[i]]['rank_1':'rank_9'].plot.bar()
    ax.set_ylim(0,1)
#fig.savefig(r'C:\Users\cip18jjp\Dropbox\PIN\Temp\LSOA_income_distributions.pdf', format = 'pdf')

# %%
#Creating empirical income distributions
bounds = [0, 5000, 10000, 15000, 20000, 30000, 40000, 50000, 60000, 150000] #income bounds
bounds = minmax_scale(bounds)

income_dists=[]
b_params = np.zeros((len(idx), 4))
bin_no = 20



fig = plt.figure(figsize=(18,16))
fig.suptitle('LSOA income distribution sample', fontsize=16)
ax0 = fig.add_subplot(5,5,1)

for i in range(len(idx)):
    count = sheff_lsoa_pop['KS101EW0001'].values[idx[i]]
    count = count * sheff_lsoa_income.iloc[idx[i]]['rank_1':'rank_9'].values
    count = count.astype(int)
    ax = fig.add_subplot(5,5,i+1, sharex = ax0, sharey = ax0)
    x = []
    for j in range(len(count)):
        if j == 0:
            x.append(np.random.uniform(low = bounds[j], high = bounds[j], size = count[j]))
        else:
            x.append(np.random.uniform(low = bounds[j], high = bounds[j + 1], size = count[j]))
    x = np.concatenate(x, axis = 0)
    income_dists.append(x)
    
    ax.hist(x, bins = bin_no, density = True)
    ax.set_ylabel("Count")
    ax.set_xlabel("Income")
    ax.set_xlim(0,1)
    
    #Fitting beta functions
    b_params[i, 0], b_params[i, 1], b_params[i, 2], b_params[i, 3] = stats.beta.fit(income_dists[i], loc = 0, scale = 1)
    ax.plot(np.linspace(0,1,100),  stats.beta.pdf(np.linspace(0,1,100), b_params[i, 0], b_params[i, 1], loc = b_params[i, 2], scale = b_params[i, 3]) )
    
fig.savefig(r'C:\Users\cip18jjp\Dropbox\PIN\Temp\LSOA_income_distributions.pdf', format = 'pdf')    




#Fitting beta distribution to the above
#plt.figure()
#plt.hist(income_dists[0], bins = bin_no, density = True)
#plt.ylabel(r'$count(income)$')
#plt.xlabel(r'$income$')
#plt.xlim(0,1)
#a1, b1, loc1, scale1 = stats.beta.fit(income_dists[0], loc = 0, scale = 1)###

#R = stats.beta.rvs(a1, b1, loc = loc1, scale = scale1, size = 2500)
#plt.figure()
#plt.hist(R, bins = bin_no, density = True)
#plt.xlim(0,1)

#plt.figure()
#plt.plot(np.linspace(0,1,100),  stats.beta.pdf(np.linspace(0,1,100), a1, b1, loc = loc1, scale = scale1) )
# Out:
# C:\Users\cip18jjp\Anaconda3\envs\ox\lib\site-packages\scipy\stats\_continuous_distns.py:515: RuntimeWarning: invalid value encountered in sqrt
#   sk = 2*(b-a)*np.sqrt(a + b + 1) / (a + b + 2) / np.sqrt(a*b)
# C:\Users\cip18jjp\Anaconda3\envs\ox\lib\site-packages\scipy\optimize\minpack.py:162: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)

# %%
#Fitting beta distribution to the above
bin_no = 30
plt.figure()
plt.hist(income_dists[0], bins = bin_no, density = True)
plt.ylabel(r'$count(income)$')
plt.xlabel(r'$income$')
plt.xlim(0,1)
a1, b1, loc1, scale1 = stats.beta.fit(income_dists[0], loc = 0, scale = 1)

R = stats.beta.rvs(a1, b1, loc = loc1, scale = scale1, size = 2500)
plt.figure()
plt.hist(R, bins = bin_no, density = True)
plt.xlim(0,1)

plt.figure()
plt.plot(np.linspace(0,1,100),  stats.beta.pdf(np.linspace(0,1,100), a1, b1, loc = loc1, scale = scale1) )

# %%
count = sheff_lsoa_pop['KS101EW0001'].values[0]
count = count * sheff_lsoa_income.iloc[0]['rank_1':'rank_9'].values
count = count.astype(int)
sheff_lsoa_pop['KS101EW0001'].values[0]
# Out:
# 1658

# %%
#Education Distribution
"""
Find in the atlas.
"""

sheff_lsoa_education = geopandas.read_file(r"C:\Users\cip18jjp\Dropbox\PIN\1 Data\1 Data\CDRC\Census Data Pack\Sheffield\tables\KS501EW_lsoa11.csv")


#Creating variables for education labels
#no_qual = ['KS501EW0014']
#lev1 = ['KS501EW0015']
#lev2 = ['KS501EW0016']
#apprenticeship = ['KS501EW0017']
#lev3 = ['KS501EW0018']
#lev4 = ['KS501EW0019']
#other = ['KS501EW0020']

sheff_lsoa_education.rename(columns={"KS501EW0002":"No qual.", "KS501EW0003":"Lev. 1", "KS501EW0004":"Lev. 2", "KS501EW0005":"Apprent.",
                                    "KS501EW0006":"Lev. 3", "KS501EW0007":"Lev 4", "KS501EW0008":"Other"}, inplace=True)

#Indexing 25 evenly spaced from array
idx = np.round(np.linspace(0, len(sheff_lsoa_education) - 1, 25)).astype(int)

fig = plt.figure(figsize=(18,16))
fig.suptitle('LSOA Education distribution sample', fontsize=16)

ax0 = fig.add_subplot(5,5,1)
for i in range(len(idx)):
    ax = fig.add_subplot(5,5,i+1, sharex = ax0, sharey = ax0)
    vals = sheff_lsoa_education.iloc[idx[i]][2:9]
    vals = pd.to_numeric(vals)
    ax.set_ylim(0,2000)
    ax = vals.plot.bar()
#fig.savefig(r'C:\Users\cip18jjp\Dropbox\PIN\Temp\LSOA_education_distributions.pdf', format = 'pdf')

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-330-43b8ab0ee963> in <module>
#       1 b_params = np.zeros((4, len(idx)))
# ----> 2 b_params[5,5]
#
# IndexError: index 5 is out of bounds for axis 0 with size 4

# %%
# Out:
#       lsoa11cd  rank_1  rank_2  rank_3  rank_4  rank_5  rank_6  rank_7  \
# 0    E01007464   0.005   0.102   0.175   0.232   0.174   0.164   0.053
# 1    E01007465   0.002   0.119   0.197   0.218   0.168   0.148   0.055
# 2    E01007466   0.001   0.139   0.193   0.215   0.175   0.163   0.032
# 3    E01007467   0.002   0.117   0.181   0.218   0.191   0.164   0.048
# 4    E01007468   0.002   0.079   0.193   0.213   0.140   0.194   0.079
# ..         ...     ...     ...     ...     ...     ...     ...     ...
# 701  E01033276   0.010   0.179   0.055   0.025   0.020   0.022   0.014
# 702  E01033277   0.003   0.113   0.188   0.239   0.198   0.145   0.032
# 703  E01033278   0.004   0.103   0.191   0.232   0.195   0.157   0.042
# 704  E01033279   0.002   0.110   0.208   0.227   0.190   0.155   0.031
# 705  E01033280   0.003   0.088   0.141   0.148   0.116   0.167   0.107
#
#      rank_8  rank_9  no_info  \
# 0     0.021   0.002    0.072
# 1     0.019   0.001    0.073
# 2     0.010   0.001    0.070
# 3     0.015   0.002    0.063
# 4     0.031   0.010    0.059
# ..      ...     ...      ...
# 701   0.006   0.001    0.669
# 702   0.009   0.000    0.072
# 703   0.013   0.003    0.060
# 704   0.011   0.001    0.066
# 705   0.090   0.033    0.107
#
#                                               geometry
# 0    POLYGON ((453490.358 408614.098, 453490.033 40...
# 1    POLYGON ((452974.779 408559.090, 452964.000 40...
# 2    POLYGON ((453215.000 408213.000, 453216.000 40...
# 3    POLYGON ((453636.000 407793.000, 453636.478 40...
# 4    POLYGON ((452594.528 411206.507, 452619.188 41...
# ..                                                 ...
# 701  POLYGON ((434853.291 387758.154, 434854.492 38...
# 702  POLYGON ((435642.000 391989.000, 435641.211 39...
# 703  POLYGON ((440448.588 383277.000, 440434.999 38...
# 704  POLYGON ((441175.029 383265.479, 441149.132 38...
# 705  POLYGON ((431113.103 392187.821, 431094.348 39...
#
# [706 rows x 12 columns]

# %%
sheff_lsoa_income
# Out:
#       lsoa11cd  rank_1  rank_2  rank_3  rank_4  rank_5  rank_6  rank_7  \
# 0    E01007464   0.005   0.102   0.175   0.232   0.174   0.164   0.053
# 1    E01007465   0.002   0.119   0.197   0.218   0.168   0.148   0.055
# 2    E01007466   0.001   0.139   0.193   0.215   0.175   0.163   0.032
# 3    E01007467   0.002   0.117   0.181   0.218   0.191   0.164   0.048
# 4    E01007468   0.002   0.079   0.193   0.213   0.140   0.194   0.079
# ..         ...     ...     ...     ...     ...     ...     ...     ...
# 701  E01033276   0.010   0.179   0.055   0.025   0.020   0.022   0.014
# 702  E01033277   0.003   0.113   0.188   0.239   0.198   0.145   0.032
# 703  E01033278   0.004   0.103   0.191   0.232   0.195   0.157   0.042
# 704  E01033279   0.002   0.110   0.208   0.227   0.190   0.155   0.031
# 705  E01033280   0.003   0.088   0.141   0.148   0.116   0.167   0.107
#
#      rank_8  rank_9  no_info  \
# 0     0.021   0.002    0.072
# 1     0.019   0.001    0.073
# 2     0.010   0.001    0.070
# 3     0.015   0.002    0.063
# 4     0.031   0.010    0.059
# ..      ...     ...      ...
# 701   0.006   0.001    0.669
# 702   0.009   0.000    0.072
# 703   0.013   0.003    0.060
# 704   0.011   0.001    0.066
# 705   0.090   0.033    0.107
#
#                                               geometry
# 0    POLYGON ((453490.358 408614.098, 453490.033 40...
# 1    POLYGON ((452974.779 408559.090, 452964.000 40...
# 2    POLYGON ((453215.000 408213.000, 453216.000 40...
# 3    POLYGON ((453636.000 407793.000, 453636.478 40...
# 4    POLYGON ((452594.528 411206.507, 452619.188 41...
# ..                                                 ...
# 701  POLYGON ((434853.291 387758.154, 434854.492 38...
# 702  POLYGON ((435642.000 391989.000, 435641.211 39...
# 703  POLYGON ((440448.588 383277.000, 440434.999 38...
# 704  POLYGON ((441175.029 383265.479, 441149.132 38...
# 705  POLYGON ((431113.103 392187.821, 431094.348 39...
#
# [706 rows x 12 columns]
